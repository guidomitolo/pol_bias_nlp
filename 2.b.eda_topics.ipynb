# %% [markdown]
# ## Exploratory Data Analisys
# ### Derecha Diario

# %% [markdown]
# ### Load tokens

# %%
import pandas as pd

# %%
token_df = pd.read_pickle('tokens/topic_tokens_der.pkl')

# %%
token_df
# Out:
#           topics  abajo  abandonara  abandone  abastecimiento  abatida  \
# doc1   inflation      0           0         0               0        0
# doc2   inflation      0           0         0               0        0
# doc3   inflation      0           0         0               0        0
# doc4   inflation      0           0         0               0        0
# doc5   inflation      0           0         0               0        0
# ...          ...    ...         ...       ...             ...      ...
# doc57   exchange      0           0         0               0        0
# doc58   exchange      0           0         0               0        0
# doc59   exchange      0           0         0               0        0
# doc60   exchange      0           0         0               0        0
# doc61   exchange      0           0         0               0        0
#
#        abierta  abierto  aboga  abonados  ...  woyecheszen  xx  yaguarete  \
# doc1         0        0      0         0  ...            0   1          0
# doc2         0        0      0         0  ...            0   0          0
# doc3         0        0      0         0  ...            0   0          0
# doc4         0        0      0         0  ...            0   0          0
# doc5         0        0      0         0  ...            0   0          0
# ...        ...      ...    ...       ...  ...          ...  ..        ...
# doc57        0        0      0         0  ...            0   0          0
# doc58        0        0      0         0  ...            0   0          0
# doc59        0        0      0         0  ...            0   0          0
# doc60        0        0      0         0  ...            0   0          0
# doc61        0        1      0         0  ...            0   0          0
#
#        york  ypf  yuanes  zamora  zona  zonaprop  zonas
# doc1      0    0       0       0     0         0      0
# doc2      0    0       0       0     0         0      1
# doc3      0    0       0       0     0         0      0
# doc4      0    0       0       0     2         2      0
# doc5      1    0       0       0     0         0      0
# ...     ...  ...     ...     ...   ...       ...    ...
# doc57     0    0       0       0     0         0      0
# doc58     0    0       0       0     0         0      0
# doc59     0    0       0       0     0         0      0
# doc60     0    0       0       0     0         0      0
# doc61     0    0       0       0     0         0      0
#
# [61 rows x 4700 columns]

# %% [markdown]
# Get docs by topics

# %% [markdown]
# ### Count words in/between doc(s)

# %% [markdown]
# #### Inflation topics

# %%
inflation = token_df[token_df.topics == 'inflation'].drop('topics', axis=1)

# %%
def count_words(df):
    top_words = {}
    for column in df.transpose().columns:
        top = df.transpose()[column].sort_values(ascending=False).head(30)
        top_words[column] = list(zip(top.index, top.values))
    return top_words

# %%
top_words = count_words(inflation)

# %%
for doc, words in top_words.items():
    print(f'{doc}\n{list((word, num) for word, num in words)}\n-------------')
# Out:
# doc1
# [('inflacion', 8), ('precios', 8), ('monetaria', 7), ('argentina', 5), ('dinero', 5), ('aumento', 4), ('mas', 4), ('convertibilidad', 3), ('elaboracion', 3), ('demanda', 3), ('variacion', 3), ('base', 3), ('economia', 3), ('alta', 3), ('exitosamente', 2), ('pais', 2), ('perdida', 2), ('nivel', 2), ('explicar', 2), ('mayores', 2), ('comportamiento', 2), ('pudo', 2), ('adquisitivo', 2), ('oferta', 2), ('partir', 2), ('tambien', 2), ('diferencias', 2), ('cualquier', 2), ('poder', 2), ('controles', 2)]
# -------------
# doc2
# [('mas', 7), ('inflacion', 5), ('aumentos', 5), ('aumentaron', 4), ('octubre', 4), ('promedio', 4), ('dato', 3), ('general', 3), ('encima', 3), ('registraron', 3), ('mes', 3), ('precios', 3), ('fuerte', 3), ('pais', 2), ('bienes', 2), ('servicios', 2), ('vestir', 2), ('estacional', 2), ('bebidas', 2), ('caracter', 2), ('dinero', 2), ('mientras', 2), ('cifras', 2), ('region', 2), ('monetario', 2), ('cerro', 2), ('alimentos', 2), ('trepo', 2), ('anualizada', 2), ('global', 2)]
# -------------
# doc3
# [('economia', 8), ('maduro', 6), ('mas', 3), ('anos', 3), ('manera', 3), ('informacion', 3), ('hace', 3), ('venezuela', 3), ('nacional', 3), ('octubre', 2), ('venezolano', 2), ('precios', 2), ('cada', 2), ('inflacion', 2), ('hiperinflacion', 2), ('menor', 2), ('llevo', 2), ('congreso', 2), ('ano', 2), ('socialista', 2), ('lata', 2), ('asamblea', 2), ('motivo', 2), ('miseria', 2), ('datos', 2), ('regimen', 2), ('mismo', 2), ('indicando', 1), ('tercer', 1), ('comercio', 1)]
# -------------
# doc4
# [('alquileres', 6), ('mas', 6), ('precios', 6), ('lipovetzky', 6), ('mercado', 5), ('buenos', 4), ('inflacion', 4), ('aires', 4), ('legislador', 3), ('aumento', 3), ('aumentos', 3), ('anos', 3), ('segun', 3), ('mes', 3), ('iniciativa', 3), ('inmobiliario', 3), ('ley', 3), ('pro', 3), ('nueva', 2), ('alquiler', 2), ('ofertadas', 2), ('tras', 2), ('regulaciones', 2), ('sturzenegger', 2), ('provincia', 2), ('personas', 2), ('zonaprop', 2), ('ex', 2), ('julio', 2), ('vez', 2)]
# -------------
# doc5
# [('mas', 7), ('ano', 6), ('mercado', 5), ('guzman', 5), ('banco', 5), ('pesos', 4), ('financiamiento', 4), ('llevar', 3), ('publico', 3), ('calmar', 3), ('central', 3), ('gobierno', 3), ('pasada', 3), ('necesidades', 3), ('gran', 3), ('financiero', 3), ('semana', 3), ('ministro', 3), ('cifras', 2), ('dolar', 2), ('efecto', 2), ('aunque', 2), ('viene', 2), ('trimestre', 2), ('aumento', 2), ('sector', 2), ('parte', 2), ('solicitar', 2), ('medidas', 2), ('licitacion', 2)]
# -------------
# doc6
# [('confianza', 10), ('riesgo', 5), ('argentina', 4), ('arriazu', 4), ('mas', 4), ('gente', 3), ('escenario', 3), ('cambio', 3), ('fmi', 3), ('emision', 3), ('acuerdo', 3), ('si', 3), ('economia', 2), ('economica', 2), ('reservas', 2), ('manera', 2), ('gobierno', 2), ('segundo', 2), ('brecha', 2), ('tipo', 2), ('deficit', 2), ('va', 2), ('hiperinflacion', 2), ('fiscal', 2), ('economista', 2), ('cuenta', 2), ('deuda', 2), ('renegociacion', 2), ('pais', 2), ('falta', 2)]
# -------------
# doc7
# [('gobierno', 7), ('mas', 6), ('guzman', 6), ('partir', 5), ('viene', 5), ('ano', 5), ('fernandez', 5), ('alberto', 4), ('monetaria', 4), ('mercado', 4), ('millones', 3), ('habia', 3), ('pais', 3), ('ministro', 3), ('economico', 3), ('financiamiento', 3), ('fmi', 3), ('monto', 3), ('ahora', 3), ('bcra', 3), ('incluyo', 2), ('adelantos', 2), ('serie', 2), ('plan', 2), ('tambien', 2), ('parte', 2), ('oposicion', 2), ('aumento', 2), ('transitorios', 2), ('medidas', 2)]
# -------------
# doc8
# [('salario', 13), ('minimo', 7), ('us', 7), ('mas', 5), ('dolares', 5), ('argentina', 5), ('mercado', 4), ('ano', 4), ('cayo', 4), ('medido', 4), ('cambios', 3), ('solo', 3), ('actualmente', 3), ('mensuales', 3), ('haiti', 3), ('oficial', 3), ('pais', 2), ('suba', 2), ('quedando', 2), ('paises', 2), ('dolar', 2), ('tipo', 2), ('ranking', 2), ('economia', 2), ('consejo', 2), ('nivel', 2), ('lugar', 2), ('vital', 2), ('fundacion', 2), ('habia', 2)]
# -------------
# doc9
# [('precios', 9), ('mas', 8), ('aumento', 7), ('septiembre', 6), ('productos', 4), ('inflacion', 4), ('promedio', 4), ('rubro', 3), ('mes', 3), ('ipc', 3), ('bebidas', 3), ('vestir', 3), ('bienes', 3), ('prendas', 3), ('aumentos', 3), ('region', 3), ('importante', 3), ('indice', 3), ('servicios', 3), ('mensual', 2), ('cerro', 2), ('alcista', 2), ('cuarentena', 2), ('alcoholicas', 2), ('gran', 2), ('general', 2), ('practicamente', 2), ('nula', 2), ('tarifas', 2), ('subio', 2)]
# -------------
# doc10
# [('mas', 9), ('indec', 8), ('desocupacion', 7), ('inflacion', 7), ('tasa', 7), ('dato', 6), ('actividad', 5), ('mercado', 4), ('si', 4), ('universidad', 4), ('cuarentena', 4), ('septiembre', 4), ('economia', 4), ('trimestre', 3), ('buscar', 3), ('estudios', 3), ('trabajo', 3), ('informe', 3), ('habria', 3), ('precios', 3), ('nivel', 3), ('desocupados', 3), ('cuestiones', 2), ('alta', 2), ('argentina', 2), ('gran', 2), ('elevada', 2), ('efecto', 2), ('nueva', 2), ('mes', 2)]
# -------------
# doc11
# [('precios', 7), ('indice', 6), ('general', 5), ('agosto', 5), ('mas', 5), ('rubro', 4), ('inflacion', 4), ('bebidas', 4), ('aumentos', 4), ('alimentos', 4), ('gobierno', 3), ('aquellos', 3), ('aumentaron', 3), ('regulados', 3), ('enorme', 3), ('ano', 3), ('subieron', 3), ('anualizada', 3), ('promedio', 3), ('mientras', 2), ('hogar', 2), ('realidad', 2), ('torno', 2), ('mes', 2), ('ambos', 2), ('servicios', 2), ('alzas', 2), ('distorsion', 2), ('cotidiana', 2), ('sectores', 2)]
# -------------
# doc12
# [('ano', 10), ('gobierno', 8), ('inflacion', 5), ('nivel', 5), ('dolar', 5), ('cuenta', 4), ('impuesto', 4), ('proyecto', 4), ('aunque', 4), ('partir', 3), ('seria', 3), ('llegaria', 3), ('incremento', 3), ('casi', 3), ('pais', 3), ('oficial', 3), ('economia', 2), ('viene', 2), ('mercado', 2), ('promedio', 2), ('tcr', 2), ('resulta', 2), ('tener', 2), ('resultado', 2), ('solo', 2), ('segmento', 2), ('dato', 2), ('propia', 2), ('cierta', 2), ('deficit', 2)]
# -------------
# doc13
# [('precios', 15), ('monetaria', 14), ('dinero', 13), ('mas', 8), ('emision', 8), ('si', 8), ('inflacion', 7), ('argentina', 6), ('circulacion', 6), ('velocidad', 6), ('economia', 6), ('cuarentena', 6), ('nivel', 5), ('andujar', 5), ('ser', 5), ('puede', 5), ('aumento', 5), ('base', 5), ('enorme', 4), ('banco', 4), ('mismo', 4), ('hoy', 4), ('hablando', 4), ('central', 4), ('toda', 4), ('demanda', 4), ('fenomeno', 4), ('gobierno', 4), ('cualquier', 4), ('pandemia', 3)]
# -------------
# doc14
# [('julio', 6), ('gobierno', 5), ('restricciones', 3), ('dinero', 3), ('ano', 3), ('general', 3), ('millones', 3), ('solo', 3), ('demanda', 3), ('liquidez', 3), ('mes', 3), ('economia', 3), ('plazo', 3), ('medidas', 2), ('meses', 2), ('bcra', 2), ('monetaria', 2), ('principalmente', 2), ('reservas', 2), ('parecen', 2), ('similares', 2), ('primeros', 2), ('pais', 2), ('comparacion', 2), ('vio', 2), ('tan', 2), ('sino', 2), ('si', 2), ('actividad', 2), ('habia', 2)]
# -------------
# doc15
# [('precios', 12), ('inflacion', 12), ('velocidad', 7), ('monetaria', 6), ('regulados', 6), ('bienes', 6), ('comportamiento', 5), ('mas', 5), ('aumento', 5), ('servicios', 5), ('dinero', 5), ('anualizada', 4), ('cada', 4), ('economia', 4), ('ipc', 4), ('nivel', 3), ('central', 3), ('julio', 3), ('mantiene', 3), ('torno', 3), ('economica', 3), ('vez', 3), ('actividad', 3), ('circulacion', 3), ('banco', 3), ('aislamiento', 3), ('general', 3), ('mayor', 3), ('politica', 3), ('argentina', 3)]
# -------------
# doc16
# [('billetes', 16), ('moneda', 7), ('millones', 6), ('casa', 6), ('pais', 4), ('denominacion', 4), ('gobierno', 3), ('tambien', 3), ('importacion', 3), ('hacer', 3), ('mes', 3), ('politica', 3), ('banco', 3), ('central', 3), ('firmas', 2), ('aun', 2), ('inyeccion', 2), ('realidad', 2), ('mayor', 2), ('fechas', 2), ('licitacion', 2), ('junio', 2), ('dinero', 2), ('plazo', 2), ('kirchner', 2), ('mas', 2), ('economia', 2), ('bcra', 2), ('nueva', 2), ('vicepresidente', 2)]
# -------------
# doc17
# [('inflacion', 10), ('junio', 7), ('precios', 7), ('ano', 7), ('mes', 6), ('general', 5), ('indice', 4), ('pais', 4), ('nivel', 4), ('presidente', 4), ('mas', 4), ('monetaria', 4), ('politica', 3), ('problema', 3), ('fernandez', 3), ('aumento', 3), ('gobierno', 3), ('niveles', 3), ('registro', 3), ('stock', 3), ('region', 3), ('servicios', 3), ('enorme', 3), ('anterior', 3), ('promedio', 3), ('caso', 3), ('comportamiento', 2), ('pases', 2), ('real', 2), ('pesos', 2)]
# -------------
# doc18
# [('deficit', 6), ('abril', 5), ('resultado', 4), ('medicion', 4), ('importante', 4), ('criterio', 4), ('ingresos', 3), ('fiscal', 3), ('tendencia', 3), ('cuentas', 3), ('monetaria', 3), ('economico', 3), ('publicas', 3), ('emision', 3), ('aun', 3), ('aumento', 3), ('ultimo', 3), ('financiero', 3), ('base', 2), ('fuerte', 2), ('marzo', 2), ('mas', 2), ('gobierno', 2), ('seria', 2), ('ano', 2), ('terminos', 2), ('parte', 2), ('tomando', 2), ('economia', 2), ('situacion', 2)]
# -------------
# doc19
# [('purerestringieron', 1), ('mercado', 1), ('rulo', 1), ('cambiario', 1), ('zonas', 0), ('duramente', 0), ('dudas', 0), ('dulce', 0), ('duplicar', 0), ('dura', 0), ('durara', 0), ('duda', 0), ('duraria', 0), ('duras', 0), ('duro', 0), ('duros', 0), ('economia', 0), ('economiaa', 0), ('economias', 0), ('dudaron', 0), ('drasticas', 0), ('drastico', 0), ('domingo', 0), ('dolarizados', 0), ('dolarpor', 0), ('dollarlinked', 0), ('dolor', 0), ('domicilioaun', 0), ('dominado', 0), ('domino', 0)]
# -------------
# doc20
# [('medidas', 7), ('economia', 6), ('crisis', 5), ('recursos', 4), ('milei', 4), ('gobierno', 4), ('pobreza', 4), ('si', 4), ('argentina', 4), ('cuarentena', 3), ('aislamiento', 3), ('salud', 3), ('sino', 3), ('economista', 3), ('parte', 3), ('depresion', 2), ('sector', 2), ('especialmente', 2), ('actividad', 2), ('mundo', 2), ('falso', 2), ('mas', 2), ('claro', 2), ('pais', 2), ('destaco', 2), ('hambre', 2), ('medida', 2), ('economica', 2), ('capacidad', 2), ('asegura', 2)]
# -------------
# doc21
# [('gobierno', 6), ('aumento', 4), ('nivel', 4), ('nacional', 3), ('si', 3), ('estrategia', 3), ('argentina', 3), ('inflacion', 3), ('recaudacion', 3), ('podria', 3), ('caida', 3), ('mas', 2), ('impuestos', 2), ('termino', 2), ('lleva', 2), ('pesos', 2), ('economista', 2), ('pandemia', 2), ('general', 2), ('melconian', 2), ('deuda', 2), ('planteo', 2), ('objetivo', 2), ('totalmente', 2), ('ser', 2), ('desbarajuste', 2), ('desorden', 2), ('refirio', 2), ('indec', 2), ('kicillof', 2)]
# -------------
# doc22
# [('billete', 7), ('habia', 5), ('denominacion', 5), ('billetes', 4), ('idea', 4), ('nueva', 4), ('moneda', 3), ('solo', 3), ('ahora', 3), ('dias', 3), ('hacer', 3), ('pesce', 3), ('us', 3), ('decision', 2), ('fernandez', 2), ('ano', 2), ('transporte', 2), ('mercado', 2), ('capacidad', 2), ('tan', 2), ('emision', 2), ('banco', 2), ('mas', 2), ('equivalente', 2), ('bueno', 2), ('hoy', 2), ('tratado', 2), ('gestion', 2), ('impresion', 2), ('monetaria', 2)]
# -------------
# doc23
# [('trimestre', 6), ('argentina', 5), ('ano', 4), ('economica', 4), ('forma', 4), ('financiamiento', 4), ('broda', 4), ('aislamiento', 3), ('segundo', 3), ('medidas', 3), ('necesidades', 3), ('inflacion', 3), ('tambien', 3), ('cae', 2), ('parece', 2), ('ultimo', 2), ('economia', 2), ('emision', 2), ('caida', 2), ('meramente', 2), ('economista', 2), ('mundo', 2), ('mes', 2), ('podria', 2), ('default', 2), ('exterior', 2), ('tener', 2), ('hacia', 2), ('senalo', 2), ('chile', 2)]
# -------------
# doc24
# [('precios', 7), ('gran', 6), ('aumento', 4), ('inflacion', 3), ('parte', 3), ('efecto', 3), ('indice', 3), ('economica', 3), ('trata', 3), ('lejos', 2), ('ser', 2), ('medidas', 2), ('mensual', 2), ('indec', 2), ('elaborado', 2), ('monetaria', 2), ('medida', 2), ('erosion', 2), ('integral', 2), ('aislamiento', 2), ('caida', 2), ('plan', 2), ('emision', 2), ('ano', 2), ('marzo', 2), ('explican', 2), ('dato', 2), ('anticipada', 1), ('fin', 1), ('anualizada', 1)]
# -------------
# doc25
# [('va', 6), ('mercados', 5), ('comportamiento', 4), ('tipo', 4), ('gobierno', 4), ('argentino', 3), ('inflacion', 3), ('cavallo', 3), ('devaluacion', 3), ('inevitable', 3), ('medidas', 3), ('fuerte', 3), ('economia', 3), ('aislamiento', 3), ('reestructuracion', 3), ('mas', 2), ('alza', 2), ('natural', 2), ('argentinos', 2), ('paralelos', 2), ('operaciones', 2), ('dolar', 2), ('si', 2), ('deuda', 2), ('social', 2), ('opino', 2), ('plan', 2), ('ademas', 2), ('regimen', 2), ('situacion', 2)]
# -------------
# doc26
# [('aumento', 7), ('sector', 4), ('precios', 4), ('mientras', 3), ('salarios', 3), ('encima', 3), ('salarial', 3), ('variacion', 3), ('marzo', 3), ('indice', 3), ('tendencia', 3), ('febrero', 3), ('inflacion', 2), ('mes', 2), ('alcanzo', 2), ('interrupcion', 2), ('meses', 2), ('percibieron', 2), ('salario', 2), ('impacto', 2), ('real', 2), ('privado', 2), ('plazo', 2), ('publico', 2), ('corto', 1), ('actualizacion', 1), ('periodo', 1), ('mantuvieron', 1), ('aumentaron', 1), ('mantuvo', 1)]
# -------------
# doc27
# [('inflacion', 7), ('tasa', 4), ('tipo', 3), ('gobierno', 3), ('mercado', 3), ('interes', 3), ('tasas', 3), ('mas', 3), ('economia', 3), ('caida', 3), ('banco', 2), ('seria', 2), ('marzo', 2), ('aislamiento', 2), ('algun', 2), ('bancos', 2), ('busca', 2), ('incluso', 2), ('negativas', 2), ('precios', 2), ('pbi', 2), ('considerando', 2), ('puntos', 2), ('futura', 2), ('estimaciones', 2), ('abril', 2), ('bono', 2), ('emision', 2), ('esperada', 2), ('tarifas', 2)]
# -------------
# doc28
# [('inflacion', 9), ('precios', 8), ('dinero', 7), ('peso', 6), ('demanda', 6), ('emision', 5), ('pesos', 4), ('santoro', 4), ('si', 4), ('teoria', 4), ('mas', 4), ('monetaria', 4), ('monetario', 3), ('cuestion', 3), ('emitir', 3), ('alta', 3), ('solamente', 3), ('menos', 3), ('lugar', 2), ('quiere', 2), ('argentino', 2), ('tambien', 2), ('argumento', 2), ('profundidad', 2), ('contexto', 2), ('mejor', 2), ('macri', 2), ('completo', 2), ('gestion', 2), ('desaparecio', 2)]
# -------------
# doc29
# [('inflacion', 5), ('si', 3), ('actualizacion', 2), ('niveles', 2), ('mas', 2), ('marzo', 2), ('gobierno', 2), ('cuarentena', 2), ('inflacionario', 2), ('parte', 2), ('importante', 2), ('tipo', 2), ('tasa', 2), ('caso', 2), ('aumento', 2), ('sectores', 2), ('trata', 2), ('tarifas', 2), ('mensual', 2), ('valor', 1), ('muestra', 1), ('dolar', 1), ('congelamientos', 1), ('explica', 1), ('estadoademas', 1), ('tiempo', 1), ('colectivos', 1), ('mayor', 1), ('estan', 1), ('planes', 1)]
# -------------
# doc30
# [('precios', 6), ('inflacion', 4), ('mas', 4), ('emision', 3), ('vez', 3), ('crisis', 3), ('controles', 2), ('gobierno', 2), ('contraccion', 2), ('gastos', 2), ('garantizar', 2), ('razon', 2), ('oferta', 2), ('luego', 2), ('marzo', 2), ('cada', 2), ('mes', 2), ('ministerio', 2), ('si', 1), ('tornan', 1), ('pasara', 1), ('consecuente', 1), ('fuertisimos', 1), ('partir', 1), ('quieren', 1), ('altos', 1), ('alzateniendo', 1), ('torna', 1), ('fusilamiento', 1), ('enero', 1)]
# -------------
# doc31
# [('dinero', 5), ('mas', 5), ('pesos', 4), ('demanda', 4), ('tipo', 3), ('inflacion', 3), ('vale', 3), ('bienes', 3), ('central', 3), ('monetaria', 3), ('medidas', 3), ('gran', 3), ('argentina', 3), ('banco', 3), ('millones', 3), ('cantidad', 2), ('dos', 2), ('republica', 2), ('sectores', 2), ('poder', 2), ('aun', 2), ('tambien', 2), ('aclarar', 2), ('cambio', 2), ('caida', 2), ('emision', 2), ('emitir', 2), ('cuales', 2), ('oferta', 2), ('dias', 2)]
# -------------
# doc32
# [('economia', 7), ('presidente', 4), ('vez', 4), ('fiscal', 3), ('deficit', 3), ('medidas', 3), ('alberto', 3), ('precios', 2), ('paquete', 2), ('mas', 2), ('inflacion', 2), ('menor', 2), ('situacion', 2), ('recursos', 2), ('plano', 2), ('tambien', 2), ('fernandez', 2), ('sostener', 2), ('postura', 2), ('segundo', 2), ('fin', 2), ('auh', 1), ('inflacionario', 1), ('mayores', 1), ('tiempo', 1), ('raiz', 1), ('radio', 1), ('severa', 1), ('coronavirus', 1), ('desabastecimiento', 1)]
# -------------
# doc33
# [('monetaria', 5), ('gobierno', 4), ('fernandez', 3), ('actual', 3), ('politica', 3), ('inflacion', 3), ('rezago', 2), ('tener', 2), ('primeros', 2), ('vez', 2), ('puede', 2), ('tipo', 2), ('ano', 2), ('gestion', 2), ('pais', 2), ('mas', 2), ('cada', 2), ('tambien', 2), ('viene', 2), ('tendencia', 2), ('alberto', 2), ('precios', 2), ('contexto', 2), ('situacion', 1), ('control', 1), ('negociacion', 1), ('usar', 1), ('bajar', 1), ('agotarse', 1), ('permanece', 1)]
# -------------

# %%
from collections import Counter

# %%
words = []
for docs, w_counts in top_words.items():
    for word in list(word for word, num in w_counts):
        words.append(word)

# %%
for word_count in Counter(words).most_common()[:50]:
    print(word_count)
# Out:
# ('mas', 27)
# ('inflacion', 23)
# ('precios', 17)
# ('economia', 17)
# ('gobierno', 17)
# ('aumento', 13)
# ('ano', 13)
# ('monetaria', 12)
# ('pais', 11)
# ('mes', 11)
# ('argentina', 10)
# ('emision', 10)
# ('si', 10)
# ('mercado', 9)
# ('medidas', 9)
# ('dinero', 8)
# ('nivel', 8)
# ('tambien', 8)
# ('general', 7)
# ('banco', 7)
# ('tipo', 7)
# ('parte', 6)
# ('aislamiento', 6)
# ('marzo', 6)
# ('demanda', 5)
# ('promedio', 5)
# ('servicios', 5)
# ('vez', 5)
# ('pesos', 5)
# ('central', 5)
# ('gran', 5)
# ('dolar', 5)
# ('economica', 5)
# ('fernandez', 5)
# ('indice', 5)
# ('cuarentena', 5)
# ('caida', 5)
# ('comportamiento', 4)
# ('partir', 4)
# ('aumentos', 4)
# ('dato', 4)
# ('bienes', 4)
# ('anualizada', 4)
# ('cada', 4)
# ('nueva', 4)
# ('viene', 4)
# ('deficit', 4)
# ('economista', 4)
# ('millones', 4)
# ('habia', 4)

# %% [markdown]
# #### Currency exchange topics

# %%
exchange = token_df[token_df.topics == 'exchange'].drop('topics', axis=1)

# %%
top_words = count_words(exchange)

# %%
for doc, words in top_words.items():
    print(f'{doc}\n{list((word, num) for word, num in words)}\n-------------')
# Out:
# doc34
# [('inflacion', 6), ('mobius', 5), ('hoy', 4), ('hanke', 3), ('dia', 3), ('argentina', 3), ('anual', 3), ('indole', 2), ('steve', 2), ('publicas', 2), ('problema', 2), ('mundo', 2), ('dolarizacion', 2), ('ano', 2), ('estimacion', 2), ('empresas', 2), ('mark', 2), ('nivel', 2), ('sino', 2), ('hiperinflacion', 2), ('ejecutivo', 2), ('indec', 2), ('recomendaciones', 2), ('describio', 2), ('metodologia', 2), ('ultimos', 2), ('internacional', 2), ('actual', 2), ('deficit', 2), ('rapida', 1)]
# -------------
# doc35
# [('transacciones', 5), ('inflacion', 4), ('local', 3), ('credito', 3), ('dolar', 3), ('parte', 3), ('hiperinflacion', 3), ('partir', 3), ('mas', 3), ('venezolana', 3), ('venezolano', 3), ('poder', 3), ('moneda', 3), ('bolivar', 2), ('operaciones', 2), ('pais', 2), ('conversaciones', 2), ('tipo', 2), ('parcial', 2), ('solamente', 2), ('gobierno', 2), ('historia', 2), ('legalizacion', 2), ('economia', 2), ('monetaria', 2), ('financieras', 2), ('caso', 2), ('fines', 2), ('region', 2), ('pesar', 2)]
# -------------
# doc36
# [('dolar', 9), ('banco', 5), ('hoy', 4), ('dia', 4), ('parte', 3), ('mas', 3), ('pais', 3), ('caida', 3), ('ubica', 3), ('us', 3), ('pesos', 3), ('subio', 3), ('millones', 3), ('medidas', 2), ('ccl', 2), ('semana', 2), ('bonos', 2), ('paralelo', 2), ('mayores', 2), ('empresas', 2), ('firmas', 2), ('perdieron', 2), ('tipo', 2), ('brecha', 2), ('impuesto', 2), ('operaciones', 2), ('cotizacion', 2), ('tambien', 2), ('oficial', 2), ('libre', 2)]
# -------------
# doc37
# [('bono', 7), ('nacional', 6), ('tesoro', 6), ('mercado', 6), ('pesos', 5), ('gobierno', 5), ('tipo', 5), ('cambio', 5), ('dolar', 4), ('expectativas', 4), ('guzman', 4), ('vencimiento', 4), ('tiempo', 3), ('pasado', 3), ('millones', 3), ('bonos', 3), ('enorme', 3), ('oficial', 3), ('ofertas', 3), ('semana', 3), ('medidas', 3), ('monto', 3), ('licitacion', 3), ('quitar', 2), ('ultimos', 2), ('competitivo', 2), ('presion', 2), ('seran', 2), ('espera', 2), ('alza', 2)]
# -------------
# doc38
# [('dolar', 8), ('mas', 8), ('fiscal', 3), ('devaluacion', 3), ('gobierno', 3), ('centavos', 3), ('mientras', 3), ('dia', 3), ('financiero', 3), ('divisa', 3), ('libre', 3), ('ayer', 3), ('guzman', 2), ('oficial', 2), ('seria', 2), ('pais', 2), ('local', 2), ('banco', 2), ('ministro', 2), ('deficit', 2), ('viernes', 2), ('cambio', 2), ('blue', 2), ('continua', 2), ('semana', 2), ('posibles', 2), ('ubica', 1), ('basicos', 1), ('siete', 1), ('inmediato', 1)]
# -------------
# doc39
# [('mercado', 6), ('biden', 6), ('laboral', 5), ('obama', 5), ('trump', 4), ('economia', 4), ('administracion', 4), ('si', 4), ('tasa', 4), ('recuperacion', 4), ('aumento', 4), ('medidas', 3), ('informe', 3), ('incentivos', 3), ('trabajo', 3), ('hoover', 3), ('ingreso', 3), ('actividad', 2), ('importante', 2), ('estudio', 2), ('reduciria', 2), ('potencial', 2), ('crecimiento', 2), ('habia', 2), ('impuesto', 2), ('ralentizacion', 2), ('presentado', 2), ('presion', 2), ('tasas', 2), ('democrata', 2)]
# -------------
# doc40
# [('usd', 10), ('millones', 9), ('dolar', 6), ('enero', 4), ('octubre', 4), ('ganancias', 3), ('parte', 3), ('moneda', 3), ('caso', 2), ('aun', 2), ('gobierno', 2), ('valores', 2), ('reservas', 2), ('ayer', 2), ('banco', 2), ('central', 2), ('mientras', 2), ('privados', 2), ('impuesto', 2), ('alicuota', 2), ('record', 2), ('extranjera', 2), ('recargo', 2), ('oficial', 2), ('ahora', 2), ('debajo', 2), ('libre', 2), ('depositos', 2), ('pais', 2), ('continua', 1)]
# -------------
# doc41
# [('dolar', 6), ('mas', 6), ('mercado', 4), ('vez', 3), ('tipo', 3), ('impuesto', 3), ('suba', 3), ('cada', 3), ('caos', 3), ('incertidumbre', 3), ('hoy', 3), ('gobierno', 3), ('tan', 2), ('banco', 2), ('termino', 2), ('central', 2), ('torno', 2), ('ascendio', 2), ('efecto', 2), ('respecto', 2), ('fracaso', 2), ('aumento', 2), ('guzman', 2), ('vio', 2), ('solo', 2), ('valores', 2), ('semana', 2), ('pasada', 2), ('alberto', 2), ('cambiario', 2)]
# -------------
# doc42
# [('guzman', 4), ('medidas', 4), ('gobierno', 4), ('demanda', 4), ('millones', 3), ('cuarentena', 3), ('habia', 3), ('solo', 3), ('nuevas', 3), ('tipo', 3), ('parece', 3), ('indica', 2), ('ano', 2), ('bajo', 2), ('normalizacion', 2), ('bancario', 2), ('confianza', 2), ('mes', 2), ('mayor', 2), ('acuerdo', 2), ('pesos', 2), ('partir', 2), ('sistema', 2), ('recrear', 2), ('todas', 2), ('mientras', 2), ('economia', 2), ('marzo', 2), ('cambio', 2), ('alza', 2)]
# -------------
# doc43
# [('dolarizacion', 5), ('mas', 4), ('gobierno', 4), ('pesos', 4), ('peso', 4), ('dolar', 4), ('hanke', 4), ('fracaso', 3), ('podria', 3), ('problema', 3), ('proceso', 3), ('inflacionario', 3), ('pasivos', 3), ('economia', 3), ('tipo', 3), ('convertibilidad', 3), ('monetaria', 3), ('medidas', 3), ('central', 3), ('argentina', 3), ('ahora', 2), ('monetario', 2), ('moneda', 2), ('presidente', 2), ('gran', 2), ('habia', 2), ('mercado', 2), ('cambio', 2), ('valor', 2), ('ecuador', 2)]
# -------------
# doc44
# [('dolar', 10), ('ayer', 6), ('banco', 5), ('central', 4), ('pesce', 4), ('hoy', 4), ('mientras', 4), ('mas', 3), ('cambio', 3), ('decir', 3), ('centavos', 3), ('dolares', 3), ('oficial', 3), ('medidas', 3), ('guzman', 3), ('devaluacion', 3), ('oferta', 3), ('venta', 3), ('mercado', 3), ('nuevas', 2), ('divisas', 2), ('llego', 2), ('tipo', 2), ('nuevo', 2), ('pesar', 2), ('esquema', 2), ('interes', 2), ('mantuvo', 2), ('bcra', 2), ('final', 2)]
# -------------
# doc45
# [('dolar', 7), ('bancos', 6), ('banco', 4), ('gobierno', 3), ('jornada', 3), ('operaciones', 3), ('dia', 3), ('cambiario', 3), ('final', 3), ('blue', 3), ('contexto', 3), ('pais', 3), ('ahorro', 3), ('central', 3), ('aunque', 3), ('economia', 3), ('nuevo', 2), ('medidas', 2), ('guzman', 2), ('ministro', 2), ('dolares', 2), ('segmento', 2), ('mercado', 2), ('lunes', 2), ('tipo', 2), ('paralelo', 2), ('vender', 2), ('continua', 2), ('economistas', 2), ('parte', 2)]
# -------------
# doc46
# [('blue', 6), ('dolares', 4), ('comprar', 4), ('presidente', 4), ('gobierno', 3), ('nuevas', 3), ('moneda', 3), ('divisa', 3), ('compra', 3), ('mas', 3), ('dolar', 3), ('central', 3), ('mercado', 3), ('banco', 3), ('pais', 3), ('ir', 3), ('miguel', 3), ('medida', 2), ('oficial', 2), ('record', 2), ('impuesto', 2), ('venta', 2), ('despues', 2), ('devaluacion', 2), ('medidas', 2), ('efecto', 2), ('cepo', 2), ('adicional', 2), ('angel', 2), ('condujeron', 2)]
# -------------
# doc47
# [('mercado', 13), ('ahorro', 9), ('dolares', 9), ('dolar', 9), ('oficial', 6), ('impuesto', 6), ('nuevas', 5), ('cuenta', 5), ('blue', 4), ('van', 4), ('gobierno', 4), ('mes', 4), ('mas', 4), ('brecha', 4), ('ingresos', 3), ('titulos', 3), ('ser', 3), ('ganancias', 3), ('medidas', 3), ('va', 3), ('bancos', 3), ('tener', 3), ('hacer', 3), ('pesos', 3), ('tarjeta', 3), ('credito', 3), ('cambio', 3), ('compras', 3), ('poder', 3), ('cambiario', 3)]
# -------------
# doc48
# [('dolar', 7), ('cerro', 6), ('mercado', 5), ('brecha', 5), ('semana', 5), ('operaciones', 4), ('mas', 4), ('pais', 4), ('bonos', 4), ('incremento', 4), ('guzman', 3), ('puntos', 3), ('tipo', 3), ('respecto', 3), ('cambio', 3), ('bolsa', 3), ('dolares', 2), ('libre', 2), ('nuevas', 2), ('segmento', 2), ('tenedores', 2), ('partir', 2), ('habia', 2), ('manera', 2), ('deuda', 2), ('similar', 2), ('mayorista', 2), ('bcra', 2), ('estabilizo', 2), ('negociaciones', 2)]
# -------------
# doc49
# [('brasil', 7), ('ano', 7), ('repunte', 6), ('mas', 5), ('exportaciones', 4), ('segun', 4), ('millones', 4), ('industrial', 4), ('mayo', 4), ('superavit', 4), ('junio', 4), ('sector', 3), ('pasado', 3), ('importaciones', 3), ('pesar', 3), ('actividad', 3), ('habia', 3), ('mensual', 3), ('ibge', 3), ('merma', 2), ('nivel', 2), ('cada', 2), ('flexibilizacion', 2), ('crisis', 2), ('caida', 2), ('comercial', 2), ('economia', 2), ('economica', 2), ('mes', 2), ('datos', 2)]
# -------------
# doc50
# [('plazo', 3), ('importaciones', 3), ('fondos', 3), ('lugar', 3), ('banco', 2), ('empresa', 2), ('garantia', 2), ('usd', 2), ('mayo', 2), ('mercado', 2), ('productivos', 2), ('dias', 2), ('fae', 2), ('constituidos', 2), ('sectores', 2), ('exterior', 2), ('central', 2), ('operar', 2), ('consideraria', 2), ('insumos', 2), ('instancias', 1), ('mantuvo', 1), ('ayudar', 1), ('elaboracionpodran', 1), ('contado', 1), ('autorizacion', 1), ('tratarse', 1), ('aunque', 1), ('agregar', 1), ('intentaria', 1)]
# -------------
# doc51
# [('empresa', 6), ('argentina', 6), ('caso', 5), ('millones', 5), ('manera', 4), ('argentino', 4), ('us', 3), ('fondo', 3), ('causa', 3), ('aunque', 3), ('juicio', 3), ('afrontar', 2), ('ypf', 2), ('posicion', 2), ('justicia', 2), ('pais', 2), ('solucion', 2), ('kicillof', 2), ('derechos', 2), ('si', 2), ('mas', 2), ('seria', 2), ('petersen', 2), ('apelar', 2), ('petrolera', 2), ('unidos', 2), ('aerolineas', 2), ('gobierno', 2), ('burford', 2), ('argentinas', 2)]
# -------------
# doc52
# [('dolares', 7), ('oficial', 6), ('demanda', 6), ('restricciones', 5), ('dolar', 5), ('mercado', 5), ('brecha', 5), ('aumento', 4), ('mercados', 4), ('banco', 4), ('central', 4), ('blue', 4), ('evitar', 4), ('tipo', 3), ('bcra', 3), ('compra', 3), ('divisas', 3), ('mas', 3), ('cambiaria', 3), ('mes', 3), ('importaciones', 3), ('asi', 2), ('liquidacion', 2), ('nuevo', 2), ('limite', 2), ('vez', 2), ('oficiales', 2), ('exterior', 2), ('disminuir', 2), ('reservas', 2)]
# -------------
# doc53
# [('pesos', 10), ('tasa', 9), ('peso', 7), ('ahorro', 6), ('credito', 4), ('minima', 4), ('tasas', 4), ('tipo', 4), ('interes', 4), ('mercado', 4), ('aquellos', 3), ('inflacion', 3), ('bcra', 3), ('local', 3), ('monetaria', 3), ('politica', 3), ('gobierno', 3), ('plazo', 3), ('garantia', 3), ('lugar', 3), ('expectativas', 3), ('depositos', 2), ('guzman', 2), ('primer', 2), ('algun', 2), ('cambiaria', 2), ('tenedores', 2), ('dolar', 2), ('reserva', 2), ('martin', 2)]
# -------------
# doc54
# [('dolar', 6), ('mas', 4), ('oficial', 3), ('medidas', 3), ('pesos', 3), ('millones', 3), ('decidio', 3), ('debido', 2), ('us', 2), ('paralelo', 2), ('valor', 2), ('gobierno', 2), ('mediante', 2), ('alza', 2), ('venta', 2), ('mercado', 2), ('reducido', 2), ('traves', 2), ('moneda', 2), ('toco', 1), ('bancos', 1), ('estima', 1), ('base', 1), ('central', 1), ('valores', 1), ('obligaciones', 1), ('dia', 1), ('banco', 1), ('nacional', 1), ('habia', 1)]
# -------------
# doc55
# [('control', 6), ('tipo', 6), ('mas', 5), ('cambio', 4), ('dolares', 4), ('economia', 4), ('brecha', 4), ('vez', 3), ('divisas', 3), ('encuentra', 3), ('cambiaria', 3), ('mercado', 3), ('creciente', 3), ('si', 3), ('dolar', 2), ('argentina', 2), ('exportadores', 2), ('cada', 2), ('real', 2), ('nuevamente', 2), ('liquidar', 2), ('reservas', 2), ('hacerlo', 2), ('agentes', 2), ('bcra', 2), ('incentivo', 2), ('inversion', 2), ('macri', 2), ('volvio', 2), ('rigido', 2)]
# -------------
# doc56
# [('gran', 3), ('mas', 3), ('dolares', 3), ('sector', 3), ('tener', 3), ('vez', 2), ('alza', 2), ('oportunidades', 2), ('recuperacion', 2), ('acceder', 2), ('oferta', 2), ('dolar', 2), ('espera', 2), ('construccion', 2), ('vivienda', 2), ('hoy', 2), ('aunque', 2), ('ahorro', 2), ('pesos', 2), ('cuenta', 2), ('cuarentena', 2), ('posean', 2), ('inmuebles', 2), ('segun', 1), ('cada', 1), ('cabo', 1), ('situacion', 1), ('baja', 1), ('sigue', 1), ('metro', 1)]
# -------------
# doc57
# [('parte', 2), ('rumores', 2), ('bancos', 2), ('expansion', 2), ('monetaria', 2), ('ver', 2), ('bcra', 1), ('habia', 1), ('millones', 1), ('marzo', 1), ('mil', 1), ('reflejado', 1), ('corralito', 1), ('alrededor', 1), ('dinero', 1), ('ahora', 1), ('frente', 1), ('igual', 1), ('falta', 1), ('mediados', 1), ('decidio', 1), ('problema', 1), ('mayor', 1), ('disminuir', 1), ('especulativas', 1), ('difunden', 1), ('cuenta', 1), ('pandemiala', 1), ('corriente', 1), ('prestaran', 1)]
# -------------
# doc58
# [('mas', 5), ('pesos', 5), ('dolar', 5), ('cada', 4), ('gobierno', 4), ('hoy', 4), ('afrontar', 4), ('monetaria', 3), ('cambiaria', 3), ('vez', 3), ('gran', 3), ('tipo', 2), ('monto', 2), ('expansion', 2), ('expectativas', 2), ('fernandez', 2), ('economia', 2), ('paridad', 2), ('parece', 2), ('millones', 2), ('corto', 2), ('respuesta', 2), ('distorsion', 2), ('cambio', 2), ('mercado', 2), ('valor', 2), ('plazo', 2), ('pudo', 2), ('jornada', 2), ('resulta', 2)]
# -------------
# doc59
# [('sufriendo', 1), ('nacional', 1), ('liquidez', 1), ('debido', 1), ('empresas', 1), ('decision', 1), ('combatir', 1), ('consideracion', 1), ('estan', 1), ('decretada', 1), ('cuarentena', 1), ('valores', 1), ('comision', 1), ('pandemia', 1), ('cnv', 1), ('falta', 1), ('dulce', 0), ('economia', 0), ('duros', 0), ('dolor', 0), ('duro', 0), ('duras', 0), ('duraria', 0), ('domicilioaun', 0), ('durara', 0), ('duramente', 0), ('dominado', 0), ('dura', 0), ('duplicar', 0), ('dudas', 0)]
# -------------
# doc60
# [('economia', 2), ('mercado', 2), ('finalmente', 1), ('valla', 1), ('sufre', 1), ('mas', 1), ('hoy', 1), ('marzo', 1), ('valores', 1), ('pesimistas', 1), ('constante', 1), ('vez', 1), ('inmediata', 1), ('aunque', 1), ('tambien', 1), ('market', 1), ('dicho', 1), ('acerca', 1), ('puntos', 1), ('riesgo', 1), ('indicador', 1), ('forma', 1), ('jueves', 1), ('correspondientes', 1), ('bajista', 1), ('paso', 1), ('situacion', 1), ('argentina', 1), ('conocemos', 1), ('maximo', 1)]
# -------------
# doc61
# [('pais', 3), ('dinero', 3), ('inversion', 2), ('monedas', 2), ('bancos', 2), ('moneda', 2), ('investigacion', 2), ('invertir', 2), ('centrales', 2), ('paises', 2), ('ingresos', 2), ('confianza', 2), ('alternativas', 2), ('ser', 2), ('digitales', 2), ('instituciones', 2), ('formas', 2), ('patrimonio', 2), ('hora', 2), ('estrategico', 1), ('general', 1), ('ahorrarsi', 1), ('nivel', 1), ('eficiencia', 1), ('factibles', 1), ('sistema', 1), ('percepcion', 1), ('insertarnos', 1), ('traves', 1), ('pequena', 1)]
# -------------

# %%
words = []
for docs, w_counts in top_words.items():
    for word in list(word for word, num in w_counts):
        words.append(word)

# %%
for word_count in Counter(words).most_common()[:50]:
    print(word_count)
# Out:
# ('dolar', 18)
# ('mas', 17)
# ('mercado', 16)
# ('gobierno', 14)
# ('tipo', 13)
# ('economia', 10)
# ('banco', 10)
# ('medidas', 10)
# ('pais', 9)
# ('pesos', 9)
# ('millones', 9)
# ('oficial', 9)
# ('cambio', 9)
# ('central', 9)
# ('guzman', 8)
# ('dolares', 8)
# ('hoy', 7)
# ('habia', 7)
# ('moneda', 6)
# ('impuesto', 6)
# ('vez', 6)
# ('bcra', 6)
# ('dia', 5)
# ('argentina', 5)
# ('parte', 5)
# ('monetaria', 5)
# ('semana', 5)
# ('brecha', 5)
# ('blue', 5)
# ('valores', 5)
# ('cada', 5)
# ('nuevas', 5)
# ('bancos', 5)
# ('aunque', 5)
# ('operaciones', 4)
# ('libre', 4)
# ('alza', 4)
# ('mientras', 4)
# ('mes', 4)
# ('ahorro', 4)
# ('cambiaria', 4)
# ('inflacion', 3)
# ('problema', 3)
# ('ano', 3)
# ('empresas', 3)
# ('nivel', 3)
# ('local', 3)
# ('credito', 3)
# ('partir', 3)
# ('caso', 3)

# %% [markdown]
# There are not a significant number of word repetions among documents. Therefore, the only ones to be erase would be those who habe no contextual meaning.

# %%
more_stop_words = ['dia', 'mes','dias', 'hoy', 'mas','ano','habia','aunque']

# %%
inflation.drop(more_stop_words, axis=1, inplace=True)

# %%
exchange.drop(more_stop_words, axis=1, inplace=True)

# %% [markdown]
# ### Visual Representation
# #### Words Frequency

# %%
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df = pd.read_csv('./data/derecha_econ_news.csv')
df_inflation = df.title[df.title.str.contains('inflacion|inflación|emisión|salarios|salario|indec')].values
df_exchange = df.title[df.title.str.contains('dolar|dólar|dolares|dólares|dolarización|cambio|cepo')].values

# %%
stopwords_sp = stopwords.words('spanish')
stopwords_sp = stopwords_sp + more_stop_words

# %%
plt.rcParams['figure.figsize'] = [16 , 30]
cloud = WordCloud(stopwords=stopwords_sp, background_color='white')

# %%
for index, doc in enumerate(df_inflation):
    cloud.generate(doc)
    plt.subplot(13, 3, index + 1)
    plt.imshow(cloud)
    plt.axis('off')
    
plt.show()

# %%
for index, doc in enumerate(df_exchange):
    cloud.generate(doc)
    plt.subplot(13, 3, index + 1)
    plt.imshow(cloud)
    plt.axis('off')
    
plt.show()
