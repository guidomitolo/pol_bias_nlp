# %% [markdown]
# ## Exploratory Data Analisys
# Izquierda Diario

# %% [markdown]
# ### Load tokens

# %%
import pandas as pd

# %%
token_df = pd.read_pickle('tokens/topic_tokens_izq.pkl')

# %%
token_df
# Out:
#           topics  abajo  abril  abrupta  absorber  aca  acceder  acceso  \
# doc1   inflation      0      0        0         0    0        0       0
# doc2   inflation      0      0        0         0    0        0       0
# doc3   inflation      0      0        0         0    0        0       0
# doc4   inflation      0      0        0         0    1        0       0
# doc5   inflation      0      0        0         0    0        0       0
# doc6   inflation      1      0        0         0    0        0       0
# doc7   inflation      0      0        0         0    0        1       0
# doc8   inflation      0      0        0         0    0        0       0
# doc9   inflation      0      0        0         0    0        0       0
# doc10  inflation      0      0        0         0    0        0       0
# doc11  inflation      0      0        0         0    0        0       0
# doc12  inflation      0      0        0         0    0        0       0
# doc13  inflation      0      0        0         0    0        0       0
# doc14  inflation      0      0        1         0    0        1       0
# doc15  inflation      0      0        0         0    0        0       0
# doc16  inflation      0      0        0         0    0        0       0
# doc17   exchange      0      0        0         0    0        0       1
# doc18   exchange      0      0        0         0    0        0       0
# doc19   exchange      0      0        0         0    0        0       0
# doc20   exchange      0      0        0         0    0        0       0
# doc21   exchange      0      0        0         0    0        0       0
# doc22   exchange      0      0        0         0    0        0       0
# doc23   exchange      0      1        0         0    0        0       0
# doc24   exchange      0      0        0         0    0        0       0
# doc25   exchange      0      0        0         0    0        0       0
# doc26   exchange      0      2        0         0    0        0       0
# doc27   exchange      0      0        0         1    0        0       0
# doc28   exchange      0      0        0         0    0        0       0
# doc29   exchange      0      0        0         0    0        0       0
#
#        accesorios  aceitera  ...  vpower  vuelca  vuelve  vuelven  \
# doc1            1         0  ...       0       0       0        0
# doc2            0         0  ...       0       1       0        0
# doc3            0         0  ...       0       0       0        0
# doc4            0         0  ...       2       0       0        0
# doc5            0         0  ...       0       0       0        0
# doc6            0         0  ...       0       0       0        0
# doc7            0         0  ...       0       0       0        0
# doc8            0         0  ...       0       0       0        0
# doc9            0         0  ...       0       0       0        1
# doc10           0         0  ...       0       0       0        0
# doc11           0         0  ...       0       0       0        0
# doc12           0         0  ...       0       0       0        0
# doc13           0         0  ...       0       0       0        1
# doc14           0         0  ...       0       0       0        0
# doc15           0         0  ...       0       0       0        0
# doc16           0         0  ...       0       0       0        0
# doc17           0         0  ...       0       0       0        0
# doc18           0         0  ...       0       0       0        0
# doc19           0         0  ...       0       0       1        0
# doc20           0         0  ...       0       0       0        0
# doc21           0         0  ...       0       0       0        0
# doc22           0         0  ...       0       0       0        0
# doc23           0         0  ...       0       0       0        0
# doc24           0         1  ...       0       0       0        0
# doc25           0         0  ...       0       0       0        0
# doc26           0         0  ...       0       0       0        0
# doc27           0         0  ...       0       0       0        0
# doc28           0         0  ...       0       0       0        0
# doc29           0         0  ...       0       0       0        0
#
#        vulnerables  vulneradoste  wall  yendo  yeso  ypf
# doc1             0             0     0      0     0    0
# doc2             0             0     0      0     0    0
# doc3             0             0     0      0     0    0
# doc4             0             0     0      0     0    4
# doc5             0             0     0      0     0    6
# doc6             0             0     0      0     0    0
# doc7             0             0     0      0     0    0
# doc8             0             0     0      0     0    0
# doc9             0             0     0      0     0    0
# doc10            0             0     0      0     0    0
# doc11            0             0     0      0     0    0
# doc12            0             0     0      0     2    0
# doc13            0             0     0      0     0    0
# doc14            0             1     0      0     0    0
# doc15            0             0     1      0     0    0
# doc16            0             0     0      0     0    0
# doc17            0             0     0      0     0    0
# doc18            0             0     0      0     0    0
# doc19            0             0     0      0     0    0
# doc20            0             0     0      0     0    0
# doc21            0             0     0      0     0    0
# doc22            0             0     0      0     0    0
# doc23            0             0     0      0     0    0
# doc24            0             0     0      0     0    0
# doc25            0             0     0      0     0    0
# doc26            0             0     0      0     0    0
# doc27            0             0     0      0     0    0
# doc28            0             0     1      1     0    0
# doc29            1             0     0      0     0    0
#
# [29 rows x 2035 columns]

# %% [markdown]
# Get docs by topics

# %% [markdown]
# ### Count words in/between doc(s)

# %% [markdown]
# #### Inflation topics

# %%
inflation = token_df[token_df.topics == 'inflation'].drop('topics', axis=1)

# %%
def count_words(df):
    top_words = {}
    for column in df.transpose().columns:
        top = df.transpose()[column].sort_values(ascending=False).head(30)
        top_words[column] = list(zip(top.index, top.values))
    return top_words

# %%
top_words = count_words(inflation)

# %%
for doc, words in top_words.items():
    print(f'{doc}\n{list((word, num) for word, num in words)}\n-------------')
# Out:
# doc1
# [('us', 7), ('millones', 6), ('exportaciones', 5), ('bienes', 4), ('importaciones', 4), ('interanual', 3), ('indec', 3), ('manufacturas', 2), ('octubre', 2), ('comercio', 2), ('baja', 2), ('superavit', 2), ('combustibles', 2), ('interesar', 2), ('balanza', 2), ('origen', 2), ('precios', 2), ('descenso', 2), ('exterior', 2), ('puede', 2), ('exportadores', 2), ('ano', 2), ('bajaron', 2), ('mas', 2), ('caida', 2), ('capital', 2), ('millonesel', 1), ('dolares', 1), ('tercios', 1), ('escaseanen', 1)]
# -------------
# doc2
# [('emae', 4), ('septiembre', 3), ('ia', 3), ('interanual', 3), ('economica', 2), ('ano', 2), ('relacion', 2), ('actividad', 2), ('caida', 2), ('economia', 1), ('comunicaciones', 1), ('publicado', 1), ('rem', 1), ('pasar', 1), ('suba', 1), ('direccion', 1), ('mensual', 1), ('bcra', 1), ('mercado', 1), ('patronales', 1), ('meses', 1), ('contraera', 1), ('beneficio', 1), ('pbi', 1), ('pedido', 1), ('nueve', 1), ('reparaciones', 1), ('sociales', 1), ('ultimo', 1), ('central', 1)]
# -------------
# doc3
# [('incremento', 3), ('aumento', 2), ('box', 2), ('particulares', 2), ('productos', 2), ('marcas', 2), ('mientras', 2), ('anunciado', 2), ('quedan', 1), ('gobierno', 1), ('lmcomo', 1), ('toca', 1), ('pasado', 1), ('tobacco', 1), ('lucky', 1), ('economica', 1), ('recien', 1), ('tabacaleros', 1), ('american', 1), ('aplico', 1), ('pasara', 1), ('aumenta', 1), ('dinamica', 1), ('contar', 1), ('habia', 1), ('trimestral', 1), ('pauperrimo', 1), ('diferentes', 1), ('ultima', 1), ('justificar', 1)]
# -------------
# doc4
# [('shell', 6), ('aumento', 5), ('ypf', 4), ('combustibles', 4), ('precios', 3), ('marca', 3), ('suba', 3), ('formula', 2), ('fin', 2), ('lunes', 2), ('goteo', 2), ('economia', 2), ('diesel', 2), ('diciembre', 2), ('cuenta', 2), ('octubre', 2), ('pasa', 2), ('inflacion', 2), ('impacto', 2), ('aumentos', 2), ('incremento', 2), ('subas', 2), ('ajuste', 2), ('vpower', 2), ('similar', 2), ('ano', 2), ('proximas', 1), ('luego', 1), ('mal', 1), ('manera', 1)]
# -------------
# doc5
# [('ypf', 6), ('aumento', 5), ('combustibles', 3), ('buscando', 3), ('aumentos', 3), ('asi', 3), ('promedio', 3), ('vez', 3), ('precios', 3), ('tambien', 3), ('nuevo', 2), ('comunicado', 2), ('empresa', 2), ('brechas', 2), ('justificar', 2), ('propia', 2), ('efecto', 2), ('estaciones', 2), ('petrolera', 2), ('estatal', 2), ('cada', 2), ('partir', 2), ('compania', 2), ('nielsen', 2), ('resto', 2), ('tanques', 2), ('informo', 2), ('inflacion', 2), ('servicio', 2), ('lunes', 2)]
# -------------
# doc6
# [('trabajadores', 10), ('ano', 9), ('salarios', 8), ('mismo', 7), ('inflacion', 7), ('aumento', 7), ('precios', 5), ('mes', 5), ('sector', 5), ('mientras', 5), ('menos', 4), ('sindicales', 4), ('mas', 4), ('salario', 4), ('registrados', 4), ('suba', 4), ('segun', 4), ('tambien', 3), ('paritarias', 3), ('patronales', 3), ('kilos', 3), ('agosto', 3), ('respecto', 3), ('incremento', 3), ('carne', 3), ('octubre', 3), ('desplome', 3), ('indec', 2), ('cuotas', 2), ('porcentaje', 2)]
# -------------
# doc7
# [('canasta', 5), ('trabajadores', 5), ('informe', 2), ('sectores', 2), ('necesidades', 2), ('servicios', 2), ('mas', 2), ('octubre', 2), ('aun', 2), ('aumento', 2), ('anos', 2), ('trabajo', 2), ('paritarias', 2), ('alimentaria', 2), ('valor', 2), ('precios', 2), ('indec', 2), ('luchas', 1), ('contiene', 1), ('explican', 1), ('direccion', 1), ('decenas', 1), ('trabajadorxs', 1), ('continua', 1), ('bienes', 1), ('contexto', 1), ('ganarde', 1), ('trabajador', 1), ('totalmente', 1), ('pareja', 1)]
# -------------
# doc8
# [('productos', 8), ('precios', 8), ('suba', 4), ('indice', 4), ('nacionales', 4), ('inflacion', 3), ('ipim', 3), ('nivel', 3), ('registro', 3), ('octubre', 3), ('aumento', 2), ('basicos', 2), ('mayor', 2), ('general', 2), ('variacion', 2), ('explica', 2), ('mismo', 2), ('incremento', 2), ('alza', 2), ('indec', 2), ('internos', 2), ('importados', 2), ('periodo', 2), ('promedio', 2), ('mayoristas', 2), ('gobierno', 1), ('gas', 1), ('conocer', 1), ('consecuencia', 1), ('parte', 1)]
# -------------
# doc9
# [('canasta', 7), ('basica', 4), ('ano', 3), ('familia', 3), ('alimentos', 3), ('inflacion', 3), ('dos', 3), ('indec', 3), ('octubre', 2), ('organismo', 2), ('fin', 2), ('precios', 2), ('alimentaria', 2), ('cba', 2), ('ser', 2), ('total', 2), ('mes', 2), ('suba', 2), ('incremento', 2), ('gobierno', 2), ('incluye', 2), ('paritarias', 1), ('meses', 1), ('tipo', 1), ('junta', 1), ('menores', 1), ('menos', 1), ('anos', 1), ('ningun', 1), ('trabajadores', 1)]
# -------------
# doc10
# [('aumentos', 6), ('ano', 5), ('inflacion', 4), ('provincia', 4), ('va', 4), ('precios', 4), ('mes', 3), ('mas', 3), ('alimentos', 2), ('empleo', 2), ('segun', 2), ('respectivamente', 2), ('rubros', 2), ('gobierno', 2), ('aumentaron', 2), ('aumento', 2), ('canasta', 2), ('ambos', 1), ('transporte', 1), ('propio', 1), ('evalua', 1), ('bebidas', 1), ('contexto', 1), ('directamente', 1), ('parece', 1), ('golpeando', 1), ('direccion', 1), ('productos', 1), ('paritarias', 1), ('alcanza', 1)]
# -------------
# doc11
# [('precios', 5), ('suba', 2), ('mes', 2), ('bebidas', 2), ('alimentos', 2), ('promedio', 2), ('fin', 2), ('inflacion', 2), ('division', 2), ('incremento', 2), ('registro', 2), ('mayor', 2), ('mas', 2), ('parte', 1), ('basica', 1), ('transporte', 1), ('anola', 1), ('golpe', 1), ('gobierno', 1), ('anoen', 1), ('ano', 1), ('medicion', 1), ('grasas', 1), ('octubre', 1), ('alcoholicas', 1), ('dio', 1), ('alto', 1), ('empresas', 1), ('jueves', 1), ('registraron', 1)]
# -------------
# doc12
# [('construccion', 8), ('industria', 5), ('datos', 3), ('septiembre', 2), ('sector', 2), ('insumos', 2), ('segun', 2), ('yeso', 2), ('interanual', 2), ('registraron', 2), ('descenso', 2), ('mismo', 2), ('trabajo', 2), ('ano', 2), ('parte', 2), ('va', 2), ('minerales', 1), ('metalicos', 1), ('ministerio', 1), ('cales', 1), ('senalo', 1), ('calcareos', 1), ('mes', 1), ('mosaicos', 1), ('muebles', 1), ('muestran', 1), ('rubros', 1), ('metal', 1), ('fabricacion', 1), ('bebida', 1)]
# -------------
# doc13
# [('salarios', 12), ('sector', 9), ('agosto', 7), ('privado', 5), ('registrados', 5), ('indec', 5), ('salario', 4), ('poder', 4), ('trabajadores', 4), ('publico', 4), ('mientras', 3), ('caida', 3), ('aumento', 3), ('total', 3), ('respecto', 3), ('registrado', 3), ('pandemia', 3), ('ano', 3), ('indice', 3), ('perdida', 2), ('interesar', 2), ('economia', 2), ('real', 2), ('compra', 2), ('maximos', 2), ('observatorio', 2), ('social', 2), ('siguio', 2), ('mes', 2), ('consecuencia', 2)]
# -------------
# doc14
# [('canasta', 5), ('perdida', 3), ('salario', 3), ('trabajadores', 3), ('indec', 3), ('sectores', 2), ('categoria', 2), ('puede', 2), ('interna', 2), ('interesar', 2), ('situacion', 2), ('tarifas', 2), ('actual', 2), ('deberia', 2), ('pobreza', 2), ('ano', 2), ('documento', 2), ('valor', 2), ('septiembre', 2), ('paritaria', 2), ('servicios', 2), ('bolsillo', 2), ('gobierno', 2), ('junta', 2), ('suma', 2), ('sept', 1), ('medios', 1), ('profundizado', 1), ('senala', 1), ('anunciada', 1)]
# -------------
# doc15
# [('agosto', 3), ('sectores', 3), ('mismo', 2), ('servicios', 2), ('respecto', 2), ('mes', 2), ('economica', 2), ('actividades', 2), ('actividad', 2), ('baja', 2), ('sociales', 2), ('registro', 2), ('publica', 1), ('restaurantes', 1), ('dolar', 1), ('caza', 1), ('silvicultura', 1), ('periodo', 1), ('explotacion', 1), ('registraron', 1), ('minas', 1), ('hoteles', 1), ('finalmente', 1), ('resto', 1), ('emae', 1), ('agua', 1), ('financiera', 1), ('personales', 1), ('minorista', 1), ('obligatoria', 1)]
# -------------
# doc16
# [('suba', 6), ('construccion', 4), ('indice', 3), ('agosto', 3), ('precios', 3), ('costo', 3), ('ano', 2), ('indec', 2), ('consecuencia', 2), ('respecto', 2), ('ultimo', 2), ('sector', 2), ('productos', 2), ('salarios', 2), ('reapertura', 1), ('argentina', 1), ('mano', 1), ('funcionamiento', 1), ('economica', 1), ('terrateniente', 1), ('aprovechar', 1), ('logro', 1), ('comparacion', 1), ('anunciado', 1), ('gastos', 1), ('generales', 1), ('septiembre', 1), ('gobierno', 1), ('puede', 1), ('construya', 1)]
# -------------

# %% [markdown]
# #### Plot

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid

# %%
words_graph = [dict(top_words[key][:10]) for key in top_words]

# %%
fig, axes = plt.subplots(nrows=8, ncols=2, constrained_layout=True, figsize=(10,30))

for index, (doc, ax) in enumerate(zip(words_graph, axes.flatten())):
    ax.bar(doc.keys(), doc.values())
    ax.grid(axis='y')
    ax.set_xticklabels(doc.keys(), rotation=45, ha='right')
    ax.set_title(list(top_words.keys())[index])

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Check how many times the words are repeated amid the documents of the same topic

# %%
from collections import Counter

# %%
words = []
for docs, w_counts in top_words.items():
    for word in list(word for word, num in w_counts):
        words.append(word)

# %%
for word_count in Counter(words).most_common()[:50]:
    print(word_count)
# Out:
# ('ano', 11)
# ('precios', 10)
# ('indec', 8)
# ('aumento', 8)
# ('octubre', 7)
# ('suba', 7)
# ('gobierno', 7)
# ('inflacion', 7)
# ('mes', 7)
# ('incremento', 6)
# ('mas', 5)
# ('trabajadores', 5)
# ('septiembre', 4)
# ('economica', 4)
# ('productos', 4)
# ('mismo', 4)
# ('sector', 4)
# ('paritarias', 4)
# ('agosto', 4)
# ('respecto', 4)
# ('canasta', 4)
# ('interanual', 3)
# ('combustibles', 3)
# ('interesar', 3)
# ('puede', 3)
# ('caida', 3)
# ('economia', 3)
# ('direccion', 3)
# ('mientras', 3)
# ('fin', 3)
# ('aumentos', 3)
# ('promedio', 3)
# ('salarios', 3)
# ('salario', 3)
# ('segun', 3)
# ('sectores', 3)
# ('servicios', 3)
# ('indice', 3)
# ('registro', 3)
# ('consecuencia', 3)
# ('parte', 3)
# ('alimentos', 3)
# ('registraron', 3)
# ('bienes', 2)
# ('baja', 2)
# ('descenso', 2)
# ('emae', 2)
# ('actividad', 2)
# ('patronales', 2)
# ('meses', 2)

# %% [markdown]
# #### Currency exchange news

# %%
exchange = token_df[token_df.topics == 'exchange'].drop('topics', axis=1)

# %%
top_words = count_words(exchange)

# %%
for doc, words in top_words.items():
    print(f'{doc}\n{list((word, num) for word, num in words)}\n-------------')
# Out:
# doc17
# [('dias', 5), ('dolar', 4), ('cnv', 4), ('local', 4), ('bolsa', 3), ('bonos', 3), ('mep', 3), ('moneda', 3), ('dolares', 2), ('dos', 2), ('humanas', 2), ('realizan', 2), ('receptora', 2), ('venden', 2), ('resolucion', 2), ('netos', 2), ('valor', 2), ('negociable', 2), ('plazo', 2), ('carteras', 2), ('dispuso', 2), ('brecha', 2), ('medidas', 2), ('tres', 2), ('juridicas', 2), ('extranjera', 2), ('mas', 2), ('transferencia', 2), ('alycs', 2), ('luego', 2)]
# -------------
# doc18
# [('dolar', 6), ('mientras', 3), ('dolares', 3), ('ccl', 2), ('nuevas', 2), ('fmi', 2), ('mep', 2), ('oficial', 2), ('soja', 1), ('mercados', 1), ('dia', 1), ('paralelo', 1), ('vaciadores', 1), ('mas', 1), ('conducen', 1), ('solidario', 1), ('expresan', 1), ('despues', 1), ('condensa', 1), ('subas', 1), ('costa', 1), ('parches', 1), ('pesar', 1), ('retenciones', 1), ('mayorista', 1), ('niveles', 1), ('paralelas', 1), ('subastras', 1), ('festival', 1), ('suman', 1)]
# -------------
# doc19
# [('dolar', 5), ('bonos', 3), ('deudael', 2), ('banco', 2), ('liqui', 2), ('guzman', 2), ('blue', 2), ('medida', 2), ('presion', 2), ('central', 2), ('cambio', 2), ('contado', 2), ('mayorista', 2), ('dolares', 2), ('subio', 1), ('solidario', 1), ('jueves', 1), ('puede', 1), ('emitido', 1), ('licitaciones', 1), ('tres', 1), ('mep', 1), ('dias', 1), ('us', 1), ('templeton', 1), ('rendimiento', 1), ('pases', 1), ('continuo', 1), ('ubica', 1), ('ubico', 1)]
# -------------
# doc20
# [('dolar', 4), ('deuda', 3), ('bonos', 3), ('us', 3), ('millones', 2), ('menos', 2), ('alcanzo', 2), ('blue', 2), ('brecha', 2), ('guzman', 2), ('pesos', 2), ('billete', 2), ('supera', 1), ('miercoles', 1), ('jueves', 1), ('nominalesen', 1), ('beneficia', 1), ('jornada', 1), ('financieros', 1), ('financiero', 1), ('aun', 1), ('logro', 1), ('papelitos', 1), ('afronta', 1), ('mas', 1), ('liqui', 1), ('vencimientos', 1), ('totalmente', 1), ('buscar', 1), ('solidario', 1)]
# -------------
# doc21
# [('oficial', 4), ('bonos', 4), ('dolar', 4), ('deuda', 3), ('habia', 3), ('blue', 3), ('mas', 3), ('fmi', 3), ('banco', 2), ('central', 2), ('semanas', 2), ('pedido', 2), ('ultimas', 2), ('ajuste', 2), ('piso', 2), ('guzman', 2), ('si', 2), ('luego', 2), ('medidas', 2), ('volvio', 2), ('grandes', 2), ('puede', 1), ('mantiene', 1), ('maniobras', 1), ('economia', 1), ('asi', 1), ('subir', 1), ('financiera', 1), ('financiero', 1), ('macrismo', 1)]
# -------------
# doc22
# [('us', 4), ('dolar', 4), ('bono', 3), ('millones', 3), ('pesos', 2), ('gobierno', 2), ('deuda', 2), ('cambio', 2), ('bonos', 2), ('mas', 2), ('fondos', 2), ('guzman', 2), ('restricciones', 1), ('respecto', 1), ('embargo', 1), ('expresidente', 1), ('solidario', 1), ('logro', 1), ('dolares', 1), ('nominados', 1), ('milloneste', 1), ('liquidacion', 1), ('beneficia', 1), ('total', 1), ('bicicleta', 1), ('martes', 1), ('beneficiados', 1), ('valor', 1), ('ccl', 1), ('conversion', 1)]
# -------------
# doc23
# [('fmi', 8), ('central', 7), ('mas', 6), ('banco', 6), ('millones', 6), ('pago', 5), ('gobierno', 5), ('reservas', 4), ('deuda', 4), ('fuga', 4), ('dolar', 4), ('us', 4), ('guzman', 3), ('ministro', 3), ('capitales', 3), ('puede', 3), ('endeudamiento', 3), ('deficit', 3), ('frente', 3), ('interesar', 3), ('dolares', 3), ('semana', 3), ('prestamo', 2), ('tensiones', 2), ('gran', 2), ('cambio', 2), ('ano', 2), ('mil', 2), ('economia', 2), ('anos', 2)]
# -------------
# doc24
# [('dolar', 6), ('dolares', 5), ('guzman', 5), ('grandes', 5), ('uu', 4), ('mas', 4), ('millones', 4), ('exportaciones', 4), ('problema', 3), ('agosto', 3), ('capitales', 3), ('deuda', 3), ('liquidacion', 3), ('bonos', 3), ('importaciones', 3), ('externa', 3), ('puede', 3), ('soja', 2), ('exterior', 2), ('fuga', 2), ('nuevas', 2), ('especuladores', 2), ('devaluacion', 2), ('banco', 2), ('ser', 2), ('camino', 2), ('medidas', 2), ('retenciones', 2), ('habia', 2), ('haber', 2)]
# -------------
# doc25
# [('dolar', 9), ('deuda', 5), ('bonos', 4), ('economia', 3), ('tasas', 3), ('central', 3), ('jueves', 3), ('mas', 3), ('pases', 3), ('anual', 3), ('tasa', 3), ('reducir', 2), ('bancos', 2), ('martin', 2), ('dolares', 2), ('titulos', 2), ('punto', 2), ('devaluacion', 2), ('pasivos', 2), ('linked', 2), ('pase', 2), ('guzman', 2), ('licitacion', 2), ('dias', 2), ('porcentual', 2), ('leliq', 2), ('mientras', 2), ('semana', 2), ('aportaron', 1), ('publica', 1)]
# -------------
# doc26
# [('dolar', 7), ('millones', 5), ('deuda', 5), ('pesos', 4), ('martes', 4), ('bono', 4), ('devaluacion', 3), ('estan', 3), ('emision', 3), ('economia', 3), ('cotizacion', 3), ('us', 2), ('bonos', 2), ('inflacion', 2), ('mas', 2), ('banco', 2), ('haber', 2), ('gobierno', 2), ('oficial', 2), ('meses', 2), ('puede', 2), ('hara', 2), ('grandes', 2), ('emitido', 2), ('central', 2), ('ultimos', 2), ('dias', 2), ('habia', 2), ('cotizaciones', 2), ('abril', 2)]
# -------------
# doc27
# [('dolar', 8), ('gobierno', 4), ('licitacion', 3), ('pesos', 3), ('devaluacion', 2), ('banco', 2), ('billete', 2), ('lunes', 2), ('bonos', 2), ('cotizaciones', 2), ('semana', 2), ('guzman', 2), ('fondo', 2), ('tipo', 2), ('estan', 2), ('titulos', 2), ('contado', 2), ('ganancias', 2), ('pobreza', 2), ('martes', 2), ('varios', 2), ('espera', 2), ('linked', 2), ('objetivo', 2), ('cambio', 2), ('parte', 2), ('subio', 2), ('macrimartin', 1), ('maquina', 1), ('asi', 1)]
# -------------
# doc28
# [('dolar', 7), ('viernes', 3), ('liquidacion', 2), ('mep', 2), ('oficial', 2), ('mayorista', 2), ('inflacion', 2), ('contado', 2), ('dolares', 2), ('guzman', 1), ('solidario', 1), ('haber', 1), ('cerro', 1), ('contener', 1), ('street', 1), ('suba', 1), ('alycs', 1), ('gradual', 1), ('banco', 1), ('medidas', 1), ('continuar', 1), ('busca', 1), ('nuevo', 1), ('dia', 1), ('bolsa', 1), ('blue', 1), ('ccl', 1), ('iprofesional', 1), ('ir', 1), ('hizo', 1)]
# -------------
# doc29
# [('dolar', 7), ('brecha', 3), ('medidas', 3), ('vendio', 3), ('oficial', 3), ('mayorista', 3), ('contado', 2), ('cotizacion', 2), ('interesar', 2), ('norteamericana', 2), ('ascenso', 2), ('liqui', 2), ('divisa', 2), ('mep', 2), ('pesar', 2), ('puede', 2), ('mayor', 2), ('guzman', 2), ('dolares', 2), ('quieren', 2), ('blue', 2), ('aumento', 2), ('templeton', 1), ('cerro', 1), ('oficiales', 1), ('soja', 1), ('bcra', 1), ('financiero', 1), ('medida', 1), ('ampliacion', 1)]
# -------------

# %% [markdown]
# #### Plot

# %%
words_graph = [dict(top_words[key][:10]) for key in top_words]

# %%
fig, axes = plt.subplots(nrows=7, ncols=2, constrained_layout=True, figsize=(10,30))

for index, (doc, ax) in enumerate(zip(words_graph, axes.flatten())):
    ax.bar(doc.keys(), doc.values())
    ax.grid(axis='y')
    ax.set_xticklabels(doc.keys(), rotation=45, ha='right')
    ax.set_title(list(top_words.keys())[index])

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Check how many times the words are repeated amid the documents of the same topic

# %%
words = []
for docs, w_counts in top_words.items():
    for word in list(word for word, num in w_counts):
        words.append(word)

# %%
for word_count in Counter(words).most_common()[:50]:
    print(word_count)
# Out:
# ('dolar', 13)
# ('guzman', 10)
# ('bonos', 9)
# ('dolares', 9)
# ('mas', 9)
# ('banco', 7)
# ('deuda', 7)
# ('puede', 6)
# ('mep', 5)
# ('medidas', 5)
# ('oficial', 5)
# ('solidario', 5)
# ('blue', 5)
# ('central', 5)
# ('us', 5)
# ('millones', 5)
# ('dias', 4)
# ('mayorista', 4)
# ('cambio', 4)
# ('contado', 4)
# ('pesos', 4)
# ('economia', 4)
# ('gobierno', 4)
# ('devaluacion', 4)
# ('brecha', 3)
# ('ccl', 3)
# ('fmi', 3)
# ('soja', 3)
# ('liqui', 3)
# ('jueves', 3)
# ('financiero', 3)
# ('habia', 3)
# ('grandes', 3)
# ('liquidacion', 3)
# ('martes', 3)
# ('semana', 3)
# ('haber', 3)
# ('bolsa', 2)
# ('valor', 2)
# ('tres', 2)
# ('alycs', 2)
# ('luego', 2)
# ('mientras', 2)
# ('nuevas', 2)
# ('dia', 2)
# ('pesar', 2)
# ('retenciones', 2)
# ('medida', 2)
# ('subio', 2)
# ('emitido', 2)

# %% [markdown]
# There are not a significant number of word repetions among documents. Therefore, the only ones to be erase would be those who habe no contextual meaning.

# %%
more_stop_words = ['dia', 'fin','dias', 'dos', 'mas','ano', 'asi','puede']

# %%
inflation.drop(more_stop_words, axis=1, inplace=True)

# %%
exchange.drop(more_stop_words, axis=1, inplace=True)

# %% [markdown]
# Tokens update

# %%
tokens_new = token_df.drop(more_stop_words, axis=1)

# %%
tokens_new.to_pickle('tokens/topic_tokens_izq_new.pkl')

# %% [markdown]
# ### Visual Representation
# #### Words Frequency

# %%
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df = pd.read_csv('./data/izq_econ_news.csv')
df_inflation = df.loc[df.flyer.str.contains('INFLA|INDEC|SUBA|PRECIO', na=False),'body'].values
df_exchange = df.loc[df.flyer.str.contains('BRECHA|CAMBI|RESERV', na=False), 'body'].values

# %%
stopwords_sp = stopwords.words('spanish')
stopwords_sp = stopwords_sp + more_stop_words

# %%
plt.rcParams['figure.figsize'] = [16 , 8]
cloud = WordCloud(stopwords=stopwords_sp, background_color='white')

# %%
for index, doc in enumerate(df_inflation):
    cloud.generate(doc)
    plt.subplot(4, 4, index + 1)
    plt.imshow(cloud)
    plt.axis('off')
    
plt.show()

# %%
for index, doc in enumerate(df_exchange):
    cloud.generate(doc)
    plt.subplot(4, 4, index + 1)
    plt.imshow(cloud)
    plt.axis('off')
    
plt.show()
